# %%
# %matplotlib inline
from tensorflow import keras
import tensorflow as tf
import sys
import os
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use("Solarize_Light2")
# Out:
# 2021-07-23 05:35:14.207968: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-07-23 05:35:14.208012: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Forecasting a Time Series

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offset1, offset2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offset1) * (freq1 * 10 + 10))
    series += 0.2 * np.sin((time - offset2) * (freq2 * 20 + 20))
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((7000, 50, 1), (7000, 1))

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$") if col == 0 else None)

# %%
a = np.array([[10, 11, 12], [20, 21, 22]])
a
# Out:
# array([[10, 11, 12],
#        [20, 21, 22]])

# %%
a[:, -1]
# Out:
# array([12, 22])

# %%
b = np.array([
    [
        [10, 11, 12],
        [20, 21, 22],
        [30, 31, 32],
    ],
    [
        [100, 101, 102],
        [200, 201, 202],
        [300, 301, 302],
    ]
])
b
# Out:
# array([[[ 10,  11,  12],
#         [ 20,  21,  22],
#         [ 30,  31,  32]],
#
#        [[100, 101, 102],
#         [200, 201, 202],
#         [300, 301, 302]]])

# %%
b[:, -1]
# Out:
# array([[ 30,  31,  32],
#        [300, 301, 302]])

# %% [markdown]
# ## Baseline Metrics

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 2021-07-23 01:10:09.647489: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-07-23 01:10:09.647536: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-07-23 01:10:09.647558: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (53f4363619f4): /proc/driver/nvidia/version does not exist
# 2021-07-23 01:10:09.647830: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 0.020211367

# %%
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# 2021-07-23 01:14:42.646899: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-07-23 01:14:42.647257: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3892700000 Hz
# Epoch 1/20
# 219/219 [==============================] - 1s 1ms/step - loss: 0.1001 - val_loss: 0.0545
# Epoch 2/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0379 - val_loss: 0.0266
# Epoch 3/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0202 - val_loss: 0.0157
# Epoch 4/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0116
# Epoch 5/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0103 - val_loss: 0.0098
# Epoch 6/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0089 - val_loss: 0.0087
# Epoch 7/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 8/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 9/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 10/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 11/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 12/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 13/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 14/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 15/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 16/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 17/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 18/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 19/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 20/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0042 - val_loss: 0.0042

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 719us/step - loss: 0.0042
# 0.004168086685240269

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])

# %% [markdown]
# ## Implementing a Simple RNN

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

optimizer = keras.optimizers.Adam(learning_rate=0.005)
model.compile(loss="mse", optimizer=optimizer)
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0967 - val_loss: 0.0489
# Epoch 2/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0369 - val_loss: 0.0296
# Epoch 3/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0253 - val_loss: 0.0218
# Epoch 4/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0198 - val_loss: 0.0177
# Epoch 5/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0166 - val_loss: 0.0151
# Epoch 6/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0146 - val_loss: 0.0134
# Epoch 7/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 8/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0124 - val_loss: 0.0116
# Epoch 9/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0118 - val_loss: 0.0112
# Epoch 10/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0116 - val_loss: 0.0110
# Epoch 11/20
# 219/219 [==============================] - 4s 18ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 12/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 16/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 19/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0114 - val_loss: 0.0109

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0109
# 0.010881561785936356

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])

# %% [markdown]
# ## Deep RNNs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 13s 54ms/step - loss: 0.0492 - val_loss: 0.0090
# Epoch 2/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 3/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 4/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 5/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 6/20
# 219/219 [==============================] - 12s 55ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 7/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 8/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 9/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 10/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 11/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 12/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 13/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 14/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 15/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 16/20
# 219/219 [==============================] - 12s 55ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 17/20
# 219/219 [==============================] - 12s 56ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 18/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 19/20
# 219/219 [==============================] - 12s 53ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 20/20
# 219/219 [==============================] - 12s 53ms/step - loss: 0.0032 - val_loss: 0.0029

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 1s 20ms/step - loss: 0.0029
# 0.0029105646535754204

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 9s 36ms/step - loss: 0.0232 - val_loss: 0.0052
# Epoch 2/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 3/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 4/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 5/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 6/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 7/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 8/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 9/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 10/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 11/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 12/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 13/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 14/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 15/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 16/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 17/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 18/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 19/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 20/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0029 - val_loss: 0.0026

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 1s 13ms/step - loss: 0.0026
# 0.002623624401167035

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])

# %% [markdown]
# ## Forecasting Several Time Steps Ahead

# %%
np.random.seed(43)

series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]

# %%
Y_pred.shape
# Out:
# (1, 10, 1)

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %%
X_train.shape, Y_train.shape
# Out:
# ((7000, 50, 1), (7000, 10))

# %%
series[:7000, -10:].shape
# Out:
# (7000, 10, 1)

# %%
X = X_valid
for step_ahead in range(10):
    y_pred_one = model.predict(X)[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)
    
Y_pred = X[:, n_steps:, 0]

# %%
Y_pred.shape
# Out:
# (2000, 10)

# %%
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_pred))
# Out:
# 0.027510839

# %%
Y_naive_pred = np.tile(X_valid[:, :-1], 10)
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_pred))
# Out:
# 0.027510839

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 1s 2ms/step - loss: 0.1343 - val_loss: 0.0606
# Epoch 2/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0496 - val_loss: 0.0425
# Epoch 3/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0385 - val_loss: 0.0353
# Epoch 4/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0331 - val_loss: 0.0311
# Epoch 5/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0298 - val_loss: 0.0283
# Epoch 6/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0273 - val_loss: 0.0264
# Epoch 7/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0256 - val_loss: 0.0249
# Epoch 8/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0244 - val_loss: 0.0237
# Epoch 9/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0234 - val_loss: 0.0229
# Epoch 10/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0227 - val_loss: 0.0222
# Epoch 11/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0220 - val_loss: 0.0216
# Epoch 12/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0215 - val_loss: 0.0212
# Epoch 13/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0210 - val_loss: 0.0208
# Epoch 14/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0207 - val_loss: 0.0207
# Epoch 15/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 16/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.0199
# Epoch 17/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.0195
# Epoch 18/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.0192
# Epoch 19/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 20/20
# 219/219 [==============================] - 0s 1ms/step - loss: 0.0188 - val_loss: 0.0187

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 9s 36ms/step - loss: 0.0669 - val_loss: 0.0317
# Epoch 2/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0265 - val_loss: 0.0200
# Epoch 3/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0183 - val_loss: 0.0160
# Epoch 4/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0155 - val_loss: 0.0144
# Epoch 5/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0139 - val_loss: 0.0118
# Epoch 6/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0128 - val_loss: 0.0112
# Epoch 7/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 8/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0115 - val_loss: 0.0103
# Epoch 9/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 10/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0110 - val_loss: 0.0100
# Epoch 11/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 12/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 13/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0104 - val_loss: 0.0100
# Epoch 14/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 15/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0095 - val_loss: 0.0107
# Epoch 16/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0092 - val_loss: 0.0089
# Epoch 17/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0094 - val_loss: 0.0111
# Epoch 18/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0095 - val_loss: 0.0094
# Epoch 19/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0093 - val_loss: 0.0083
# Epoch 20/20
# 219/219 [==============================] - 8s 35ms/step - loss: 0.0094 - val_loss: 0.0085

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %%
X_train.shape, Y_train.shape
# Out:
# ((7000, 50, 1), (7000, 50, 10))

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", 
              optimizer=keras.optimizers.Adam(learning_rate=0.01), 
              metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# 2021-07-23 05:36:17.238825: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-07-23 05:36:17.239162: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3892700000 Hz
# Epoch 1/20
# 219/219 [==============================] - 9s 37ms/step - loss: 0.0508 - last_time_step_mse: 0.0400 - val_loss: 0.0429 - val_last_time_step_mse: 0.0324
# Epoch 2/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0395 - last_time_step_mse: 0.0283 - val_loss: 0.0366 - val_last_time_step_mse: 0.0265
# Epoch 3/20
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0335 - last_time_step_mse: 0.0224 - val_loss: 0.0301 - val_last_time_step_mse: 0.0179
# Epoch 4/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0301 - last_time_step_mse: 0.0192 - val_loss: 0.0277 - val_last_time_step_mse: 0.0160
# Epoch 5/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0271 - last_time_step_mse: 0.0150 - val_loss: 0.0265 - val_last_time_step_mse: 0.0159
# Epoch 6/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0250 - last_time_step_mse: 0.0122 - val_loss: 0.0219 - val_last_time_step_mse: 0.0084
# Epoch 7/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0229 - last_time_step_mse: 0.0101 - val_loss: 0.0235 - val_last_time_step_mse: 0.0105
# Epoch 8/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0216 - last_time_step_mse: 0.0088 - val_loss: 0.0217 - val_last_time_step_mse: 0.0092
# Epoch 9/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0212 - last_time_step_mse: 0.0085 - val_loss: 0.0198 - val_last_time_step_mse: 0.0075
# Epoch 10/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0204 - last_time_step_mse: 0.0079 - val_loss: 0.0214 - val_last_time_step_mse: 0.0092
# Epoch 11/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0201 - last_time_step_mse: 0.0078 - val_loss: 0.0199 - val_last_time_step_mse: 0.0077
# Epoch 12/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0197 - last_time_step_mse: 0.0075 - val_loss: 0.0184 - val_last_time_step_mse: 0.0067
# Epoch 13/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0191 - last_time_step_mse: 0.0069 - val_loss: 0.0187 - val_last_time_step_mse: 0.0063
# Epoch 14/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0190 - last_time_step_mse: 0.0070 - val_loss: 0.0191 - val_last_time_step_mse: 0.0077
# Epoch 15/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0190 - last_time_step_mse: 0.0071 - val_loss: 0.0186 - val_last_time_step_mse: 0.0082
# Epoch 16/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0186 - last_time_step_mse: 0.0067 - val_loss: 0.0183 - val_last_time_step_mse: 0.0072
# Epoch 17/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0188 - last_time_step_mse: 0.0068 - val_loss: 0.0178 - val_last_time_step_mse: 0.0062
# Epoch 18/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0185 - last_time_step_mse: 0.0068 - val_loss: 0.0174 - val_last_time_step_mse: 0.0062
# Epoch 19/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0184 - last_time_step_mse: 0.0068 - val_loss: 0.0171 - val_last_time_step_mse: 0.0057
# Epoch 20/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0184 - last_time_step_mse: 0.0069 - val_loss: 0.0184 - val_last_time_step_mse: 0.0068

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)

# %% [markdown]
# ## Fighting the Unstable Gradients Problem

# %%
from tensorflow.keras.layers import LayerNormalization

# %%
class LNSimpleRNNCell(keras.layers.Layer):
    def __init__(self, units, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units, activation=None)
        self.layer_norm = LayerNormalization()
        self.activation = keras.activations.get(activation)
    
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        if inputs is not None:
            batch_size = tf.shape(inputs)[0]
            dtype = inputs.dtype
        return [tf.zeros([batch_size, self.state_size], dtype=dtype)]
    
    def call(self, inputs, states):
        outputs, new_states = self.simple_rnn_cell(inputs, states)
        norm_outputs = self.activation(self.layer_norm(outputs))
        return norm_outputs, [norm_outputs]

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True, input_shape=[None, 1]),
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 15s 63ms/step - loss: 0.1604 - last_time_step_mse: 0.1579 - val_loss: 0.0751 - val_last_time_step_mse: 0.0691
# Epoch 2/20
# 219/219 [==============================] - 13s 62ms/step - loss: 0.0667 - last_time_step_mse: 0.0576 - val_loss: 0.0601 - val_last_time_step_mse: 0.0487
# Epoch 3/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0566 - last_time_step_mse: 0.0458 - val_loss: 0.0532 - val_last_time_step_mse: 0.0416
# Epoch 4/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0506 - last_time_step_mse: 0.0386 - val_loss: 0.0473 - val_last_time_step_mse: 0.0344
# Epoch 5/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0454 - last_time_step_mse: 0.0324 - val_loss: 0.0426 - val_last_time_step_mse: 0.0290
# Epoch 6/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0405 - last_time_step_mse: 0.0269 - val_loss: 0.0378 - val_last_time_step_mse: 0.0234
# Epoch 7/20
# 219/219 [==============================] - 15s 68ms/step - loss: 0.0371 - last_time_step_mse: 0.0240 - val_loss: 0.0351 - val_last_time_step_mse: 0.0210
# Epoch 8/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0345 - last_time_step_mse: 0.0214 - val_loss: 0.0336 - val_last_time_step_mse: 0.0209
# Epoch 9/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0328 - last_time_step_mse: 0.0199 - val_loss: 0.0322 - val_last_time_step_mse: 0.0184
# Epoch 10/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0314 - last_time_step_mse: 0.0186 - val_loss: 0.0304 - val_last_time_step_mse: 0.0163
# Epoch 11/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0304 - last_time_step_mse: 0.0179 - val_loss: 0.0298 - val_last_time_step_mse: 0.0177
# Epoch 12/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0298 - last_time_step_mse: 0.0175 - val_loss: 0.0305 - val_last_time_step_mse: 0.0172
# Epoch 13/20
# 219/219 [==============================] - 13s 62ms/step - loss: 0.0287 - last_time_step_mse: 0.0162 - val_loss: 0.0285 - val_last_time_step_mse: 0.0152
# Epoch 14/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0282 - last_time_step_mse: 0.0158 - val_loss: 0.0276 - val_last_time_step_mse: 0.0156
# Epoch 15/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0277 - last_time_step_mse: 0.0154 - val_loss: 0.0273 - val_last_time_step_mse: 0.0142
# Epoch 16/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0274 - last_time_step_mse: 0.0154 - val_loss: 0.0275 - val_last_time_step_mse: 0.0152
# Epoch 17/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0268 - last_time_step_mse: 0.0147 - val_loss: 0.0264 - val_last_time_step_mse: 0.0141
# Epoch 18/20
# 219/219 [==============================] - 14s 62ms/step - loss: 0.0266 - last_time_step_mse: 0.0145 - val_loss: 0.0262 - val_last_time_step_mse: 0.0147
# Epoch 19/20
# 219/219 [==============================] - 4536s 21s/step - loss: 0.0262 - last_time_step_mse: 0.0141 - val_loss: 0.0264 - val_last_time_step_mse: 0.0130
# Epoch 20/20
# 219/219 [==============================] - 14s 65ms/step - loss: 0.0259 - last_time_step_mse: 0.0137 - val_loss: 0.0255 - val_last_time_step_mse: 0.0131

# %% [markdown]
# ## Tackling the Short-Term Memory Problem

# %% [markdown]
# ### LSTM cells

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 17s 67ms/step - loss: 0.0760 - last_time_step_mse: 0.0615 - val_loss: 0.0554 - val_last_time_step_mse: 0.0364
# Epoch 2/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0480 - last_time_step_mse: 0.0283 - val_loss: 0.0427 - val_last_time_step_mse: 0.0222
# Epoch 3/20
# 219/219 [==============================] - 14s 65ms/step - loss: 0.0391 - last_time_step_mse: 0.0181 - val_loss: 0.0367 - val_last_time_step_mse: 0.0157
# Epoch 4/20
# 219/219 [==============================] - 14s 65ms/step - loss: 0.0350 - last_time_step_mse: 0.0151 - val_loss: 0.0334 - val_last_time_step_mse: 0.0132
# Epoch 5/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0325 - last_time_step_mse: 0.0133 - val_loss: 0.0314 - val_last_time_step_mse: 0.0121
# Epoch 6/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0308 - last_time_step_mse: 0.0122 - val_loss: 0.0298 - val_last_time_step_mse: 0.0112
# Epoch 7/20
# 219/219 [==============================] - 15s 68ms/step - loss: 0.0297 - last_time_step_mse: 0.0118 - val_loss: 0.0291 - val_last_time_step_mse: 0.0120
# Epoch 8/20
# 219/219 [==============================] - 15s 66ms/step - loss: 0.0286 - last_time_step_mse: 0.0109 - val_loss: 0.0278 - val_last_time_step_mse: 0.0099
# Epoch 9/20
# 219/219 [==============================] - 15s 66ms/step - loss: 0.0280 - last_time_step_mse: 0.0108 - val_loss: 0.0278 - val_last_time_step_mse: 0.0113
# Epoch 10/20
# 219/219 [==============================] - 14s 65ms/step - loss: 0.0273 - last_time_step_mse: 0.0105 - val_loss: 0.0268 - val_last_time_step_mse: 0.0101
# Epoch 11/20
# 219/219 [==============================] - 14s 65ms/step - loss: 0.0269 - last_time_step_mse: 0.0102 - val_loss: 0.0263 - val_last_time_step_mse: 0.0096
# Epoch 12/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0264 - last_time_step_mse: 0.0101 - val_loss: 0.0263 - val_last_time_step_mse: 0.0105
# Epoch 13/20
# 219/219 [==============================] - 14s 65ms/step - loss: 0.0259 - last_time_step_mse: 0.0097 - val_loss: 0.0257 - val_last_time_step_mse: 0.0100
# Epoch 14/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0257 - last_time_step_mse: 0.0096 - val_loss: 0.0252 - val_last_time_step_mse: 0.0091
# Epoch 15/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0253 - last_time_step_mse: 0.0095 - val_loss: 0.0251 - val_last_time_step_mse: 0.0092
# Epoch 16/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0251 - last_time_step_mse: 0.0095 - val_loss: 0.0248 - val_last_time_step_mse: 0.0089
# Epoch 17/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0248 - last_time_step_mse: 0.0094 - val_loss: 0.0248 - val_last_time_step_mse: 0.0098
# Epoch 18/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0245 - last_time_step_mse: 0.0093 - val_loss: 0.0246 - val_last_time_step_mse: 0.0091
# Epoch 19/20
# 219/219 [==============================] - 14s 65ms/step - loss: 0.0242 - last_time_step_mse: 0.0091 - val_loss: 0.0238 - val_last_time_step_mse: 0.0085
# Epoch 20/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0239 - last_time_step_mse: 0.0089 - val_loss: 0.0238 - val_last_time_step_mse: 0.0086

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 1s 11ms/step - loss: 0.0238 - last_time_step_mse: 0.0086
# [0.023788683116436005, 0.008560801856219769]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)

# %% [markdown]
# ### GRU cells

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 18s 72ms/step - loss: 0.0738 - last_time_step_mse: 0.0655 - val_loss: 0.0538 - val_last_time_step_mse: 0.0450
# Epoch 2/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0476 - last_time_step_mse: 0.0367 - val_loss: 0.0441 - val_last_time_step_mse: 0.0326
# Epoch 3/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0417 - last_time_step_mse: 0.0301 - val_loss: 0.0390 - val_last_time_step_mse: 0.0275
# Epoch 4/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0368 - last_time_step_mse: 0.0243 - val_loss: 0.0339 - val_last_time_step_mse: 0.0202
# Epoch 5/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0326 - last_time_step_mse: 0.0180 - val_loss: 0.0312 - val_last_time_step_mse: 0.0164
# Epoch 6/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0306 - last_time_step_mse: 0.0155 - val_loss: 0.0294 - val_last_time_step_mse: 0.0143
# Epoch 7/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0295 - last_time_step_mse: 0.0145 - val_loss: 0.0300 - val_last_time_step_mse: 0.0162
# Epoch 8/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0283 - last_time_step_mse: 0.0135 - val_loss: 0.0278 - val_last_time_step_mse: 0.0130
# Epoch 9/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0276 - last_time_step_mse: 0.0130 - val_loss: 0.0273 - val_last_time_step_mse: 0.0127 0.0276 - last
# Epoch 10/20
# 219/219 [==============================] - 15s 69ms/step - loss: 0.0269 - last_time_step_mse: 0.0125 - val_loss: 0.0264 - val_last_time_step_mse: 0.0121
# Epoch 11/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0265 - last_time_step_mse: 0.0121 - val_loss: 0.0268 - val_last_time_step_mse: 0.0135
# Epoch 12/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0263 - last_time_step_mse: 0.0123 - val_loss: 0.0261 - val_last_time_step_mse: 0.0123
# Epoch 13/20
# 219/219 [==============================] - 16s 71ms/step - loss: 0.0258 - last_time_step_mse: 0.0116 - val_loss: 0.0254 - val_last_time_step_mse: 0.0116
# Epoch 14/20
# 219/219 [==============================] - 15s 71ms/step - loss: 0.0256 - last_time_step_mse: 0.0117 - val_loss: 0.0254 - val_last_time_step_mse: 0.0116
# Epoch 15/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0253 - last_time_step_mse: 0.0114 - val_loss: 0.0250 - val_last_time_step_mse: 0.0112
# Epoch 16/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0251 - last_time_step_mse: 0.0114 - val_loss: 0.0250 - val_last_time_step_mse: 0.0114
# Epoch 17/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0248 - last_time_step_mse: 0.0112 - val_loss: 0.0249 - val_last_time_step_mse: 0.0118
# Epoch 18/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0245 - last_time_step_mse: 0.0110 - val_loss: 0.0244 - val_last_time_step_mse: 0.0108
# Epoch 19/20
# 219/219 [==============================] - 16s 72ms/step - loss: 0.0243 - last_time_step_mse: 0.0108 - val_loss: 0.0240 - val_last_time_step_mse: 0.0105
# Epoch 20/20
# 219/219 [==============================] - 15s 70ms/step - loss: 0.0240 - last_time_step_mse: 0.0106 - val_loss: 0.0238 - val_last_time_step_mse: 0.0103

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 1s 12ms/step - loss: 0.0238 - last_time_step_mse: 0.0103
# [0.023785505443811417, 0.010262809693813324]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)

# %% [markdown]
# ### Using 1D convolutional layers to process sequences

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid", input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train[:, 3::2], epochs=20, validation_data=(X_valid, Y_valid[:, 3::2]))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 11s 40ms/step - loss: 0.0681 - last_time_step_mse: 0.0601 - val_loss: 0.0477 - val_last_time_step_mse: 0.0396
# Epoch 2/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0414 - last_time_step_mse: 0.0340 - val_loss: 0.0367 - val_last_time_step_mse: 0.0285
# Epoch 3/20
# 219/219 [==============================] - 9s 40ms/step - loss: 0.0338 - last_time_step_mse: 0.0257 - val_loss: 0.0307 - val_last_time_step_mse: 0.0218
# Epoch 4/20
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0282 - last_time_step_mse: 0.0184 - val_loss: 0.0259 - val_last_time_step_mse: 0.0152
# Epoch 5/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0249 - last_time_step_mse: 0.0143 - val_loss: 0.0246 - val_last_time_step_mse: 0.0141
# Epoch 6/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0234 - last_time_step_mse: 0.0125 - val_loss: 0.0227 - val_last_time_step_mse: 0.0115
# Epoch 7/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0226 - last_time_step_mse: 0.0117 - val_loss: 0.0225 - val_last_time_step_mse: 0.0116
# Epoch 8/20
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0220 - last_time_step_mse: 0.0111 - val_loss: 0.0216 - val_last_time_step_mse: 0.0105
# Epoch 9/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0216 - last_time_step_mse: 0.0108 - val_loss: 0.0217 - val_last_time_step_mse: 0.0109
# Epoch 10/20
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0213 - last_time_step_mse: 0.0106 - val_loss: 0.0210 - val_last_time_step_mse: 0.0102
# Epoch 11/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0210 - last_time_step_mse: 0.0102 - val_loss: 0.0208 - val_last_time_step_mse: 0.0100
# Epoch 12/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0208 - last_time_step_mse: 0.0102 - val_loss: 0.0208 - val_last_time_step_mse: 0.0102
# Epoch 13/20
# 219/219 [==============================] - 8s 38ms/step - loss: 0.0205 - last_time_step_mse: 0.0098 - val_loss: 0.0206 - val_last_time_step_mse: 0.0101
# Epoch 14/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0204 - last_time_step_mse: 0.0099 - val_loss: 0.0204 - val_last_time_step_mse: 0.0099
# Epoch 15/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0202 - last_time_step_mse: 0.0097 - val_loss: 0.0199 - val_last_time_step_mse: 0.0093
# Epoch 16/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0200 - last_time_step_mse: 0.0097 - val_loss: 0.0201 - val_last_time_step_mse: 0.0095
# Epoch 17/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0196 - last_time_step_mse: 0.0093 - val_loss: 0.0197 - val_last_time_step_mse: 0.0091
# Epoch 18/20
# 219/219 [==============================] - 8s 37ms/step - loss: 0.0194 - last_time_step_mse: 0.0090 - val_loss: 0.0192 - val_last_time_step_mse: 0.0086
# Epoch 19/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0190 - last_time_step_mse: 0.0087 - val_loss: 0.0188 - val_last_time_step_mse: 0.0084
# Epoch 20/20
# 219/219 [==============================] - 8s 36ms/step - loss: 0.0186 - last_time_step_mse: 0.0083 - val_loss: 0.0184 - val_last_time_step_mse: 0.0080

# %% [markdown]
# ### WaveNet

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))

model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 3s 10ms/step - loss: 0.0669 - last_time_step_mse: 0.0543 - val_loss: 0.0365 - val_last_time_step_mse: 0.0231
# Epoch 2/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0324 - last_time_step_mse: 0.0193 - val_loss: 0.0294 - val_last_time_step_mse: 0.0166
# Epoch 3/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0283 - last_time_step_mse: 0.0156 - val_loss: 0.0269 - val_last_time_step_mse: 0.0145
# Epoch 4/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0261 - last_time_step_mse: 0.0136 - val_loss: 0.0254 - val_last_time_step_mse: 0.0131
# Epoch 5/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0248 - last_time_step_mse: 0.0124 - val_loss: 0.0245 - val_last_time_step_mse: 0.0122
# Epoch 6/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0240 - last_time_step_mse: 0.0117 - val_loss: 0.0233 - val_last_time_step_mse: 0.0108
# Epoch 7/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0234 - last_time_step_mse: 0.0113 - val_loss: 0.0230 - val_last_time_step_mse: 0.0109
# Epoch 8/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0227 - last_time_step_mse: 0.0106 - val_loss: 0.0228 - val_last_time_step_mse: 0.0106
# Epoch 9/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0222 - last_time_step_mse: 0.0103 - val_loss: 0.0225 - val_last_time_step_mse: 0.0107
# Epoch 10/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0220 - last_time_step_mse: 0.0101 - val_loss: 0.0214 - val_last_time_step_mse: 0.0092
# Epoch 11/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0214 - last_time_step_mse: 0.0094 - val_loss: 0.0210 - val_last_time_step_mse: 0.0091
# Epoch 12/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0210 - last_time_step_mse: 0.0091 - val_loss: 0.0214 - val_last_time_step_mse: 0.0099
# Epoch 13/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0207 - last_time_step_mse: 0.0089 - val_loss: 0.0203 - val_last_time_step_mse: 0.0084
# Epoch 14/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0204 - last_time_step_mse: 0.0085 - val_loss: 0.0202 - val_last_time_step_mse: 0.0083
# Epoch 15/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0201 - last_time_step_mse: 0.0083 - val_loss: 0.0197 - val_last_time_step_mse: 0.0078
# Epoch 16/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0200 - last_time_step_mse: 0.0083 - val_loss: 0.0197 - val_last_time_step_mse: 0.0079
# Epoch 17/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0197 - last_time_step_mse: 0.0078 - val_loss: 0.0195 - val_last_time_step_mse: 0.0078
# Epoch 18/20
# 219/219 [==============================] - 2s 8ms/step - loss: 0.0193 - last_time_step_mse: 0.0075 - val_loss: 0.0192 - val_last_time_step_mse: 0.0076
# Epoch 19/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0192 - last_time_step_mse: 0.0074 - val_loss: 0.0188 - val_last_time_step_mse: 0.0071
# Epoch 20/20
# 219/219 [==============================] - 2s 9ms/step - loss: 0.0190 - last_time_step_mse: 0.0073 - val_loss: 0.0188 - val_last_time_step_mse: 0.0072
